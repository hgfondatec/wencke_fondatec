# %%
import os
import time
import pandas as pd
from sqlalchemy import create_engine

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# ---------------------------------------------------
# 1. Verbindung zur PostgreSQL-Datenbank
# ---------------------------------------------------

DB_USER = os.getenv("DB_USER", "sbs")
DB_PASS = os.getenv("DB_PASS", "qaqpav-xyxhi9-jeGmyv")
DB_HOST = os.getenv("DB_HOST", "172.30.30.5")
DB_PORT = os.getenv("DB_PORT", "5432")
DB_NAME = os.getenv("DB_NAME", "wenke")

print("Verbinde mit PostgreSQL...")

engine = create_engine(
    f"postgresql+psycopg2://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)

print("Verbindung erfolgreich.")
# Out:
# Verbinde mit PostgreSQL...
# Verbindung erfolgreich.

# %%
import pandas as pd

excel_datei = r"C:\Users\henrik.giesler\Desktop\QlikExport\Facts.xlsx"

# Alle Sheets laden
alle_sheets = pd.read_excel(excel_datei, sheet_name=None)

# Alle DataFrames zusammenführen
df_gesamt = pd.concat(alle_sheets.values(), ignore_index=True)

print(df_gesamt.shape)
print(df_gesamt.head())
# Out:
# (8301, 9)
#   ADR_Adressnummer ADR_Adressnummer_und_Name ADR_Kurzname       ADR_Name  \
# 0                                        NaN          NaN            NaN
# 1              161                       NaN          NaN            NaN
# 2             1522                       NaN          NaN            NaN
# 3            21051                       NaN          NaN            NaN
# 4           100001      100001-PARTY IM PARK     party im  Party im Park
#
#    ADR_Vertreter ADR_Adresstyp          ADR_Adreßgruppe  ADR Sammelrechnung  \
# 0            NaN           NaN                      NaN                 NaN
# 1            NaN           NaN                      NaN                 NaN
# 2            NaN           NaN                      NaN                 NaN
# 3            NaN           NaN                      NaN                 NaN
# 4          115.0        Kunden  XX - keine Adressgruppe                 1.0
#
#    ADR_Besuch IST
# 0             NaN
# 1             NaN
# ...

# %%
print("Speichere Daten in PostgreSQL...")

df_gesamt.to_sql(
    "raw_qlik_facts",
    engine,
    schema="reporting",
    if_exists="replace",
    index=False
)

print("Tabelle reporting.raw_qlik_artikelstamm gespeichert.")
# Out:
# Speichere Daten in PostgreSQL...
# Tabelle reporting.raw_qlik_artikelstamm gespeichert.
